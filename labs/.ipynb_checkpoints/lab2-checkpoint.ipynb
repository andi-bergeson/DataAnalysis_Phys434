# %%
# %matplotlib inline
import numpy as np
import math
from scipy import stats, special, signal
from matplotlib import pyplot as plt

# %% [markdown]
# # "Probability, Distributions, and Statistical Questions"
#
# ## Problem 1 - Gamma-Ray Convolution
#
# ### Quick notes on convolution... in measuring a phenomena, there is the phenomena itself, and a background signal, each with their own PDF. The convolved PDF is one which combines those PDF's in a way which can illustrate how overall shape is affected. Convolution can even be the same PDF integrated over a number of days.
#
# $$ P_{A+B}(x) = \int P_{A}(z)P_{B}(x-z)dz = P_{A}(x) \times P_{B}(x) $$

# %% [markdown]
# ### In looking for gamma-ray sources, there will be a background of discrete noise terms in our images that follow a Poisson distribution. In detecting a gamma-ray signal, we must calculate the probability that the background gives us a measurement as signal-like or higher than the signal received.
#
# ### I assume that the average cosmic-ray background on day 1 is 2 blips, and I posit that a signal of 3 or more blips on average per day corresponds to a signal emitted by our gamma-ray candidate.

# %%
blipmin,blipmax = 0,10
blips = np.linspace(blipmin,blipmax,blipmax+1)
noise = stats.poisson.pmf(k=blips,mu=2)

# %%
fig, ax = plt.subplots(1,2)
fig.set_size_inches(20,6) 

conv = noise
days = 10
for i in range(days):
    conv = signal.fftconvolve(noise,conv,mode='full')

ax[0].plot(blips,noise)
ax[0].set_xlim(days*blipmin-1,days*blipmax)
ax[0].set_title("Prob Mass Function for 1 Day of Blips",fontsize=18)

x = np.linspace(days*blipmin,days*blipmax,len(conv))
ax[1].plot(x,conv)
ax[1].set_title("Prob Mass Function for 10 Days of Blips",fontsize=18)

plt.show()

# %% [markdown]
# ### You can see that it moves to the right and grows in width as you sum for more days. The uncertainty sums with the distribution.

# %%
fig, ax = plt.subplots(1,1)
fig.set_size_inches(16,6) 

conv = noise
days = 5
for i in range(days):
    conv = signal.fftconvolve(noise,conv,mode='full')

x = np.linspace(days*blipmin,days*blipmax,len(conv))
ax.scatter(x,conv,label='Convolved PMF')

#plot a poisson
xfit = np.linspace(0,25,26)
ax.plot(xfit,stats.poisson.pmf(k=xfit,mu=2*days),label='Poisson with $\mu$=10')
ax.set_title("5 Days of Blips", fontsize=18)

ax.legend(fontsize=12);

# %% [markdown]
# ### The shift and increase in width when comparing across days do not disqualify the summed convolved PMF from fitting a Poisson... this is because no other pmf's are being multiplied against the Poisson, thus its mean changes characteristically with the day, and the spread conforms to the proportions of a Poisson.

# %%
days = [10,50,200,1000]

conv0 = noise
for i in range(days[0]):
    conv0 = signal.fftconvolve(noise,conv0,mode='full')
    
conv1 = noise
for i in range(days[1]):
    conv1 = signal.fftconvolve(noise,conv1,mode='full')
    
conv2 = noise
for i in range(days[2]):
    conv2 = signal.fftconvolve(noise,conv2,mode='full')
    
conv3 = noise
for i in range(days[3]):
    conv3 = signal.fftconvolve(noise,conv3,mode='full')

# %%
fig, ax = plt.subplots(1,2)
fig.set_size_inches(20,6) 

#plotting day 10 against day 50 and day 200

x0 = np.linspace(blipmin,blipmax,len(conv0))
ax[0].plot(x0,conv0,label='{0:g} Convolutions'.format(days[0]))

x1 = np.linspace(blipmin,blipmax,len(conv1))
ax[0].plot(x1,conv1,label='{0:g} Convolutions'.format(days[1]))

x2 = np.linspace(blipmin,blipmax,len(conv2))
ax[0].plot(x2,conv2,label='{0:g} Convolutions'.format(days[2]),c='r')

ax[0].set_title("Average Blips per day",fontsize=18)
ax[0].set_xlabel("Blips")
ax[0].set_ylabel("Probability")
ax[0].legend()

#plotting day 200 against day 1000

x2 = np.linspace(blipmin,blipmax,len(conv2))
ax[1].plot(x2,conv2,label='{0:g} Convolutions'.format(days[2]),c='r')

x3 = np.linspace(blipmin,blipmax,len(conv3))
ax[1].plot(x3,conv3,label='{0:g} Convolutions'.format(days[3]),c='g')

ax[1].set_title("Average Blips per day",fontsize=18)
ax[1].set_xlabel("Blips")
ax[1].set_ylabel("Probability")
ax[1].legend()

plt.show()

# %% [markdown]
# ### As we convolve more and more days, the width decreases by $\sqrt{N}$ (from Central Limit Theorem). The peak appears to decrease too - this is an artifact of convolution, and fixed when normalizing the PMF.
#
# ### Since the width is changing, this means the overall shape of the distribution is changing. It no longer resembles a Poisson, as we saw in B. Instead, we narrow the x-axis down to the portion of the PMF which contains the greatest overlap in each consecutive convolution, resulting in a sharp peak above the mean.
#
# ### This change in width influences our ability to make judgements as to whether or not a particular signal is likely to have originated from this distribution or not. If we see 3 blips on a given day, it is more understandable for us to get such a number if the width is larger. Constraining the width can help us confirm/deny the presence of a signal that is extremely unlikely to have originated from noise.

# %%
# likelihood of seeing a signal of 3 or more

p10 = 0
ptot = 0
for i in range(len(conv0)):
    add = (x0[i]-x0[i-1])*conv0[i]
    ptot += add
    if x0[i] > 2.99999:
        aaa = (x0[i]-x0[i-1])*conv0[i]
        p10 += aaa
    ratio10 = 1. - (p10/ptot)
    
p50 = 0
ptot = 0
for i in range(len(conv1)):
    add = (x1[i]-x1[i-1])*conv1[i]
    ptot += add
    #
    if x1[i] > 2.99999:
        aaa = (x1[i]-x1[i-1])*conv1[i]
        p50 += aaa
    ratio50 = 1. - (p50/ptot)
    
sig10 = stats.norm.ppf(ratio10)
sig50 = stats.norm.ppf(ratio50)

print("\nA signal of 3 blips on a given day corresponds to {0:.5f} sigma in a 10-Convolution distribution, and a {1:.5f} sigma in a 50-C distribution.".format(
sig10,sig50))
# Out:
# A signal of 3 blips on a given day corresponds to 2.12281 sigma in a 10-Convolution distribution, and a 4.67305 sigma in a 50-C distribution.

# %% [markdown]
# # Problem 2 - Rayleigh Convolution
#
# ### Convolving a Rayleigh allows us to watch a Non-Symmetric distribution change as it convolves with itself. Since it is not multi-modal, we expect the peak to maintain its position over our arbitrary value of 1, and our width to decrease with $\sqrt{N}$.

# %%
xmin,xmax = 0,6
x = np.linspace(xmin,xmax,8)
ray = stats.rayleigh.pdf(x,loc=1.,scale=1.)

t = [5,18,30,40,2]

con5 = ray
for i in range(t[0]):
    con5 = signal.fftconvolve(ray,con5,mode='full')

con18 = ray
for i in range(t[1]):
    con18 = signal.fftconvolve(ray,con18,mode='full')
    
con30 = ray
for i in range(t[2]):
    con30 = signal.fftconvolve(ray,con30,mode='full')
    
con40 = ray
for i in range(t[3]):
    con40 = signal.fftconvolve(ray,con40,mode='full')
    
con2 = ray
for i in range(t[4]):
    con2 = signal.fftconvolve(ray,con2,mode='full')
    
x5 = np.linspace(xmin,xmax,len(con5))
x18 = np.linspace(xmin,xmax,len(con18))
x30 = np.linspace(xmin,xmax,len(con30))
x40 = np.linspace(xmin,xmax,len(con40))
x2 = np.linspace(xmin,xmax,len(con2))

# %%
fig, ax = plt.subplots(2,2)
fig.set_size_inches(22,10) 

x = np.linspace(xmin,xmax,30)

ax[0,0].plot(x,stats.rayleigh.pdf(x,loc=1.,scale=1.),label='Rayleigh without Convolution')
ax[0,0].plot(x2,con2,label='{0:g} Convolutions'.format(t[4]))
ax[0,0].plot(x5,con5,label='{0:g} Convolutions'.format(t[0]))
ax[0,0].plot(x18,con18,label='{0:g} Convolutions'.format(t[1]))

ax[0,0].set_title("Rayleigh Convolutions",fontsize=18)
ax[0,0].set_xlabel("x")
ax[0,0].set_ylabel("Probability")
ax[0,0].legend()
    

ax[0,1].plot(x,stats.rayleigh.pdf(x,loc=1.,scale=1.),label='Rayleigh without Convolution')
ax[0,1].plot(x2,con2,label='{0:g} Convolutions'.format(t[4]))
ax[0,1].plot(x5,con5,label='{0:g} Convolutions'.format(t[0]))
ax[0,1].plot(x18,con18,label='{0:g} Convolutions'.format(t[1]))
ax[0,1].set_yscale('log')
ax[0,1].set_ylim(10**-17)

ax[0,1].set_title("Semi-log Probability",fontsize=18)
ax[0,1].set_xlabel("x")
ax[0,1].set_ylabel("Probability")
ax[0,1].legend()


ax[1,0].plot(x40,con40,label='{0:g} Convolutions'.format(t[3]))
ax[1,0].plot(x30,con30,label='{0:g} Convolutions'.format(t[2]))

ax[1,0].set_title("Rayleigh Convolutions",fontsize=18)
ax[1,0].set_xlabel("x")
ax[1,0].set_ylabel("Probability")
ax[1,0].legend()


ax[1,1].plot(x30,con30,label='{0:g} Convolutions'.format(t[2]))
ax[1,1].plot(x40,con40,label='{0:g} Convolutions'.format(t[3]))
ax[1,1].plot(x,stats.norm.pdf(x,loc=2.25,scale=.11),label='Gaussian')
ax[1,1].set_yscale('log')
ax[1,1].set_ylim(10**-16)

ax[1,1].set_title("Semi-log Probability",fontsize=18)
ax[1,1].set_xlabel("x")
ax[1,1].set_ylabel("Probability")
ax[1,1].legend()

plt.show()

# %% [markdown]
# ### We can see in the final plot that by 40 Convolutions, we approach a Gaussian in all aspects except left tail, where the Rayleigh is predictibly steeper. The distribution follows Central limit theorem as it smooths out and looks more and more Gaussian with higher convolutions.

# %% [markdown]
# # Problem 3 - Mergers
#
# ### I am now going to simulate data for images taken in the UV of a point source (an object occupying only one pixel). After dividing by a flat, the thermal noise background from the CCD (dark current) appears as a zero-mean Gaussian with constant width of 1.5 over the image.
#
# ### The image taken of the coordinate pointed out by LIGO and SWIFT has a floating point brightness of 8.5 (this CCD is not sensitive enoguh to count single photons, so our image pulls from a continuous distribution).

# %%
imdim = 256   #number of pixels
image = np.linspace(0,imdim,imdim+1)
thermal = stats.norm.pdf(image,loc=0.,scale=1.5)

swift = stats.norm.ppf(stats.norm.cdf(8.5,loc=0.,scale=1.5))

print("\nIf the pixel value of 8.5 is from thermal noise, it would be a {0:.5f} sigma signal from that distribution.".format(swift))
print("\nSince sigma's of larger than 5 are traditionally considered a valid detection, I would claim discovery of a Neutron Star Merger.\n")
# Out:
# If the pixel value of 8.5 is from thermal noise, it would be a 5.66667 sigma signal from that distribution.
#
# Since sigma's of larger than 5 are traditionally considered a valid detection, I would claim discovery of a Neutron Star Merger.

# %% [markdown]
# ### Now let's say we have an alert from LIGO about a gravitational wave, but no visual signal from SWIFT - either because this merger involves a black hole, or because SWIFT wasn't pointing in the right place.
#
# ### When looking for a signal in an image of 10k pixels, we are checking each pixel one by one. Statistically, we are curious as to what the probability density function of the background is after we commit to 10k trials of measurement.

# %%
image = np.linspace(-1.,10.,12)
thermal = stats.norm.pdf(image,loc=0.,scale=1.5)

merge = thermal
for i in range(900):
    merge = signal.fftconvolve(thermal,merge,mode='full')

# %%
fig, ax = plt.subplots(2,2)
fig.set_size_inches(22,10)

ax[0,0].plot(image,thermal)
ax[0,0].set_title("Original Background Distribution", fontsize=18)

ax[0,1].plot(np.linspace(-1,10,len(merge)),merge,label='Convolved')
tryingtofit = np.linspace(-1,10,20)
ax[0,1].plot(tryingtofit,stats.norm.pdf(tryingtofit,loc=0.45,scale=0.09)/10**66,label='Gaussian fit')
ax[0,1].set_title("10k-Pixel Image Convolution", fontsize=18);
ax[0,1].legend(fontsize=14)

ax[1,0].plot(image,thermal*1000)
ax[1,0].set_title("Semi-Log Original Background Distribution", fontsize=18)
ax[1,0].set_yscale('log')

ax[1,1].plot(np.linspace(-1,10,len(merge)),merge)
ax[1,1].set_title("Semi-Log 10k-Pixel Image Convolution", fontsize=18);
ax[1,1].set_yscale('log')
ax[1,1].set_ylim(10**-82);

# %%
yep = stats.norm.cdf(8.5,loc=0.45,scale=0.09)
kajsd = stats.norm.ppf(yep)
kajsd
# Out:
# inf

# %% [markdown]
# ### With each time the pixels are measured and thus drawn from a Gaussian, we must convolve the function. This function is so small that a signal of 8.5 lies wayyyy outside the normal mean, as seen from "inf" above (massive sigma).
#
# ### I believe this section to have been intended to illustrate that the more trials you make, the more likely your narrowing peak will assign previously reasonable & noisy values to larger sigmas, thus increasing the frequency of incorrect "5 sigma discoveries".
